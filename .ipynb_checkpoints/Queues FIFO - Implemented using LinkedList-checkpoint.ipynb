# %%
#Queue FIFO
# Usecase why Queue ?: 
# Many People sending docs, cv to centralised Printer ,
# Now printer has jobs to complete. So how to printer organise 
# them internally?

# Another User case
# Reservation for flight / bus/ train booking also maintains queue to 
# cater to user requests

#There are many applications in OS for Processes/ P
# rograms Using Queue

# Operations on Queue are Enqueue and Dequeue

# Enqueue( Add to Queue)
# Queue is implemeted using Array or Linkedlist
# there is Head and Tail in Queue
# Always inserted at tail end
#O(1) time complexity


# Dequeue(Remove from Queue)
# Always deleted from head end
#O(1) time complexity


# Implement a Queue using LinkedList

class Node:
    def __init__(self, info, next=None):
        self.info=info
        self.next=next
class Queue:
    def __init__(self):
        self.front=self.rear=None
        
    def EnQueue(self,ele):
        temp=Node(ele)
        if self.rear==None:
            self.rear=self.front=temp
            return
        self.rear.next=temp
        self.rear=temp
    def isEmpty(self):
        return self.front==None
    
    def DeQueue(self):
        if self.isEmpty():
            print("Queue is Empty")
            return
        else:
            temp=self.front
            self.front=temp.next
            if self.front==None:
                self.rear==None
    def display(self):
        p=self.front
        while(p!=None):
            print(p.info)
            p=p.next
            
            
q =Queue()
q.EnQueue(10)
q.EnQueue(20)
q.EnQueue(30)
q.display()
print("*****")
q.DeQueue( )
q.display()
    
        
        
    
    
#Circular Array Implementation using Arrays upto 'N' values

#Linear array Implementation ( Will not be able to store 'N' values)
# Out:
# 10
# 20
# 30
# *****
# 20
# 30
